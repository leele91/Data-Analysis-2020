# %% [markdown]
# ## 워드 클라우드

# %% [markdown]
# ### 설치
# - conda install -c conda-forge wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# ## alice in wonderland

# %%
text = open('./data/Alice.txt').read()
stopwords = set(STOPWORDS)
stopwords.add('said')

# %%
print(stopwords)
# Out:
# {'has', 'himself', "we're", 'an', 'ourselves', "i've", 'was', 'while', 'however', 'otherwise', 'above', 'doing', 'also', "i'm", 'off', 'can', 'she', 'theirs', 'yours', 'said', "they're", 'down', 'from', "when's", 'could', 'cannot', 'com', 'into', 'if', "wasn't", 'myself', 'ought', 'up', 'under', "haven't", 'it', "you'll", 'through', 'before', "you'd", 'in', 'be', 'having', "shouldn't", 'as', "doesn't", 'herself', 'or', 'too', 'these', 'yourself', 'www', 'of', "they'll", "that's", "aren't", "we've", 'for', 'is', 'over', "we'll", 'why', 'am', "what's", 'here', 'hers', "let's", 'nor', "wouldn't", "there's", 'get', 'you', "don't", "he'd", 'k', 'once', "you're", 'on', 'her', "he'll", 'to', 'like', "i'll", 'with', 'would', 'r', 'when', 'did', 'i', 'there', 'are', 'him', 'other', 'against', 'whom', 'does', "hasn't", 'he', 'this', 'had', "i'd", "we'd", "who's", 'have', 'so', 'do', 'just', 'below', 'how', 'most', 'his', 'same', 'then', "won't", "here's", 'again', 'should', "she'll", 'therefore', 'they', "it's", 'what', 'hence', 'than', 'your', 'all', 'both', 'http', 'them', 'their', 'and', "how's", "couldn't", 'own', 'been', 'which', 'being', 'because', "didn't", 'during', "they'd", 'each', "they've", 'very', 'until', "you've", 'after', "she's", 'ever', 'themselves', 'a', 'between', 'that', 'few', 'since', 'some', "hadn't", "she'd", 'at', 'by', 'we', 'who', "where's", 'no', "shan't", "why's", 'but', 'my', 'yourselves', "isn't", 'else', 'out', 'those', 'only', 'such', 'our', "can't", "weren't", 'the', 'about', 'itself', "mustn't", 'any', 'not', 'ours', 'where', 'further', 'shall', 'its', 'more', 'me', 'were', "he's"}

# %%
wc = WordCloud(background_color='white', max_words=2000, stopwords=stopwords)
wc = wc.generate(text)

# %%
# words_단어의 빈도수를 볼 수 있다.
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}: {values[i]}')
# Out:
# Alice: 1.0
# little: 0.29508196721311475
# one: 0.27595628415300544
# know: 0.2459016393442623
# went: 0.226775956284153
# thing: 0.2185792349726776
# time: 0.2103825136612022
# Queen: 0.20765027322404372
# see: 0.1830601092896175
# King: 0.17486338797814208

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 그림에 표시하기

# %%
mask = np.array(Image.open('./data/Alice_mask.png'))
plt.figure(figsize=(8,8))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=mask, stopwords=stopwords)
wc = wc.generate(text)

# %%
plt.figure(figsize=(8,8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Star Wars - A New Hope

# %%
text = open('./data/A_new_hope.txt').read()
text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('./data/Stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add("int")
stopwords.add("ext")

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords, margin=10, random_state=1).generate(text)

default_colors = wc.to_array()

# %%
import random
def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' %random.randint(60,100)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3), interpolation='bilinear')
plt.axis('off')
plt.show()
